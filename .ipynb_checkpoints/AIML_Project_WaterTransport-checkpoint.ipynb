# %% [markdown]
# # CNN Water Transport
# ## AI & ML Project Part B
#
# **Objective:**
# To predict images whether it is cruise ship, submarine, boat, hovercraft, or cargo ship with high accuracy.
#
# **Models Used:**
# - Keras
#
# **Web Server Prediction:**
# - Web Localhost
# - Upload image for predict

# %%
import warnings 
warnings.simplefilter(action='ignore')
import sys
print(sys.executable)
# Out:
# C:\Users\kenne\anaconda3\envs\tf\python.exe

# %%
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
